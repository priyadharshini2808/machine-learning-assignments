# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/elcot/Desktop/Fraud_check.csv")

# %%
data.head()
# Out:
#   Undergrad   Marital  Income  Experience Urban
# 0        NO    Single   68833          10   YES
# 1       YES  Divorced   33700          18   YES
# 2        NO   Married   36925          30   YES
# 3       YES    Single   50190          15   YES
# 4        NO   Married   81002          28    NO

# %%
inputs=data.drop('Income',axis='columns')

# %%
target=data['Income']

# %%
target.head()
# Out:
# 0    68833
# 1    33700
# 2    36925
# 3    50190
# 4    81002
# Name: Income, dtype: int64

# %%
x = data['Income']

# %%
x.head(3)
# Out:
# 0    68833
# 1    33700
# 2    36925
# Name: Income, dtype: int64

# %%
data.head(3)
# Out:
#   Undergrad   Marital  Income  Experience Urban
# 0        NO    Single   68833          10   YES
# 1       YES  Divorced   33700          18   YES
# 2        NO   Married   36925          30   YES

# %%
data['Income']=data['Income'].apply(lambda x:"1" if x>=30000 else "0")

# %%
data.head(3)
# Out:
#   Undergrad   Marital Income  Experience Urban
# 0        NO    Single      1          10   YES
# 1       YES  Divorced      1          18   YES
# 2        NO   Married      1          30   YES

# %%
inputs.head()
# Out:
#   Undergrad   Marital  Experience Urban
# 0        NO    Single          10   YES
# 1       YES  Divorced          18   YES
# 2        NO   Married          30   YES
# 3       YES    Single          15   YES
# 4        NO   Married          28    NO

# %%
target_1=data['Income']

# %%
target_1.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Income, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_Undergrad = LabelEncoder()
le_Marital = LabelEncoder()
le_Urban = LabelEncoder()

# %%
inputs['Undergrad_n']=le_Undergrad.fit_transform(inputs['Undergrad'])
inputs['Marital_n']=le_Undergrad.fit_transform(inputs['Marital'])
inputs['Urban_n']=le_Undergrad.fit_transform(inputs['Urban'])

# %%
inputs.head()
# Out:
#   Undergrad   Marital  Experience Urban  Undergrad_n  Marital_n  Urban_n
# 0        NO    Single          10   YES            0          2        1
# 1       YES  Divorced          18   YES            1          0        1
# 2        NO   Married          30   YES            0          1        1
# 3       YES    Single          15   YES            1          2        1
# 4        NO   Married          28    NO            0          1        0

# %%
inputs_n=inputs.drop(['Undergrad','Marital','Urban','Experience'],axis='columns')

# %%
inputs_n.head()
# Out:
#    Undergrad_n  Marital_n  Urban_n
# 0            0          2        1
# 1            1          0        1
# 2            0          1        1
# 3            1          2        1
# 4            0          1        0

# %%
data['Undergrad_n']=le_Undergrad.fit_transform(data['Undergrad'])
data['Marital_n']=le_Undergrad.fit_transform(data['Marital'])
data['Urban_n']=le_Undergrad.fit_transform(data['Urban'])

# %%
data.head(5)
# Out:
#   Undergrad   Marital Income  Experience Urban  Undergrad_n  Marital_n  \
# 0        NO    Single      1          10   YES            0          2
# 1       YES  Divorced      1          18   YES            1          0
# 2        NO   Married      1          30   YES            0          1
# 3       YES    Single      1          15   YES            1          2
# 4        NO   Married      1          28    NO            0          1
#
#    Urban_n
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0

# %%
data1=data.drop(['Undergrad','Marital','Urban','Experience'],axis='columns')

# %%
data1.head(5)
# Out:
#   Income  Undergrad_n  Marital_n  Urban_n
# 0      1            0          2        1
# 1      1            1          0        1
# 2      1            0          1        1
# 3      1            1          2        1
# 4      1            0          1        0

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(data1,test_size = 0.2)

# %%
train.head()
# Out:
#     Income  Undergrad_n  Marital_n  Urban_n
# 233      0            0          1        1
# 563      1            1          1        1
# 252      1            0          2        1
# 204      0            0          1        0
# 570      1            0          2        1

# %%
test.head()
# Out:
#     Income  Undergrad_n  Marital_n  Urban_n
# 23       1            0          2        1
# 163      0            1          0        1
# 394      1            0          0        1
# 211      1            1          1        1
# 325      1            0          2        1

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
help(DecisionTreeClassifier)
# Out:
# Help on class DecisionTreeClassifier in module sklearn.tree.tree:
#
# class DecisionTreeClassifier(BaseDecisionTree, sklearn.base.ClassifierMixin)
#  |  DecisionTreeClassifier(criterion='gini', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, class_weight=None, presort=False)
#  |
#  |  A decision tree classifier.
#  |
#  |  Read more in the :ref:`User Guide <tree>`.
#  |
#  |  Parameters
#  |  ----------
#  |  criterion : string, optional (default="gini")
#  |      The function to measure the quality of a split. Supported criteria are
#  |      "gini" for the Gini impurity and "entropy" for the information gain.
#  |
#  |  splitter : string, optional (default="best")
#  |      The strategy used to choose the split at each node. Supported
#  |      strategies are "best" to choose the best split and "random" to choose
# ...

# %%
model = DecisionTreeClassifier(criterion = 'entropy')

# %%
inputs1=data1.drop('Income',axis='columns')

# %%
inputs1.head(5)
# Out:
#    Undergrad_n  Marital_n  Urban_n
# 0            0          2        1
# 1            1          0        1
# 2            0          1        1
# 3            1          2        1
# 4            0          1        0

# %%
target1=data1['Income']

# %%
target1.head(5)
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Income, dtype: object

# %%
model.fit(X=train[inputs1], y=train[target1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-a78173b4b4dd> in <module>
# ----> 1 model.fit(X=train[inputs1], y=train[target1])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2912         # Do we have a (boolean) DataFrame?
#    2913         if isinstance(key, DataFrame):
# -> 2914             return self._getitem_frame(key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_frame(self, key)
#    3007     def _getitem_frame(self, key):
#    3008         if key.values.size and not is_bool_dtype(key.values):
# -> 3009             raise ValueError('Must pass DataFrame with boolean values only')
#    3010         return self.where(key)
#    3011
#
# ValueError: Must pass DataFrame with boolean values only

# %%
train,test = data[data['is_train'] == True],data[data['is_train']==False]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'is_train'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-3f698ba2ef55> in <module>
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(data,test_size = 0.2)

# %%
from sklearn.tree import  DecisionTreeClassifier

# %%
help(DecisionTreeClassifier)
# Out:
# Help on class DecisionTreeClassifier in module sklearn.tree.tree:
#
# class DecisionTreeClassifier(BaseDecisionTree, sklearn.base.ClassifierMixin)
#  |  DecisionTreeClassifier(criterion='gini', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, class_weight=None, presort=False)
#  |
#  |  A decision tree classifier.
#  |
#  |  Read more in the :ref:`User Guide <tree>`.
#  |
#  |  Parameters
#  |  ----------
#  |  criterion : string, optional (default="gini")
#  |      The function to measure the quality of a split. Supported criteria are
#  |      "gini" for the Gini impurity and "entropy" for the information gain.
#  |
#  |  splitter : string, optional (default="best")
#  |      The strategy used to choose the split at each node. Supported
#  |      strategies are "best" to choose the best split and "random" to choose
# ...

# %%
model = DecisionTreeClassifier(criterion = 'entropy')

# %%
model.fit(train[inputs_n],train[target_1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-00b976eb35fd> in <module>
# ----> 1 model.fit(train[inputs_n],train[target_1])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2912         # Do we have a (boolean) DataFrame?
#    2913         if isinstance(key, DataFrame):
# -> 2914             return self._getitem_frame(key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_frame(self, key)
#    3007     def _getitem_frame(self, key):
#    3008         if key.values.size and not is_bool_dtype(key.values):
# -> 3009             raise ValueError('Must pass DataFrame with boolean values only')
#    3010         return self.where(key)
#    3011
#
# ValueError: Must pass DataFrame with boolean values only
